# %%
from csdp_pipeline.pipeline_elements.mne_sleep_dataset import sleep_dataset_from_paths

edf_path = r"O:\Tech_BISON\data\real\sourcedata\sub002\PSG2\PSYKPROJEKT_sub002-2.edf"

channels = sleep_dataset_from_paths.get_available_channels([edf_path])
print(channels)
# Out:
# c:\Users\runer\Documents\common-sleep-data-pipeline\csdp_pipeline\pipeline_elements\mne_sleep_dataset.py:191: RuntimeWarning: Channel names are not unique, found duplicates for: {'EMG'}. Applying running numbers for duplicates.
#   return mne.io.read_raw_edf(filename,preload=preload,verbose=False)
# c:\Users\runer\Documents\common-sleep-data-pipeline\csdp_pipeline\pipeline_elements\mne_sleep_dataset.py:191: RuntimeWarning: Channels contain different highpass filters. Highest filter setting will be stored.
#   return mne.io.read_raw_edf(filename,preload=preload,verbose=False)
# c:\Users\runer\Documents\common-sleep-data-pipeline\csdp_pipeline\pipeline_elements\mne_sleep_dataset.py:191: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   return mne.io.read_raw_edf(filename,preload=preload,verbose=False)
# ...

# %%
from csdp_training.experiments.bids_predictor_single_file import score_file

labels, epochs_used, avg_outputs = score_file(
    input_path=edf_path,
    eeg_inputs=["F4:M1", "C4:M1"],
    eog_inputs=["E1:M2", "E2:M1"],
    checkpoint="C:\\Users\\runer\\Documents\\common-sleep-data-pipeline\\weights\\best-usleep.ckpt",
    output_path="test/result",  # saves result.npz + result.png
)

print(f"Scored {len(labels)} epochs")
# Out:
# W0517 15:36:10.716000 18692 Lib\site-packages\torch\utils\flop_counter.py:29] triton not found; flop counting will not work for triton kernels
# c:\Users\runer\Documents\common-sleep-data-pipeline\csdp_pipeline\pipeline_elements\mne_sleep_dataset.py:191: RuntimeWarning: Channel names are not unique, found duplicates for: {'EMG'}. Applying running numbers for duplicates.
#   return mne.io.read_raw_edf(filename,preload=preload,verbose=False)
# c:\Users\runer\Documents\common-sleep-data-pipeline\csdp_pipeline\pipeline_elements\mne_sleep_dataset.py:191: RuntimeWarning: Channels contain different highpass filters. Highest filter setting will be stored.
#   return mne.io.read_raw_edf(filename,preload=preload,verbose=False)
# c:\Users\runer\Documents\common-sleep-data-pipeline\csdp_pipeline\pipeline_elements\mne_sleep_dataset.py:191: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
# ...

# %%
import numpy as np

stage_names = {0: "W", 1: "R", 2: "N1", 3: "N2", 4: "N3"}
valid = labels[~np.isnan(labels)].astype(int)
for stage, name in stage_names.items():
    print(f"{name}: {np.sum(valid == stage)} epochs")
# Out:
# W: 220 epochs
# R: 168 epochs
# N1: 67 epochs
# N2: 455 epochs
# N3: 126 epochs
